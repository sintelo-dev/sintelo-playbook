# %% [markdown]
# # 04 – Modeling
# ## AdventureWorks | Capital Operativo
#
# **Propósito**
# Modelar métricas relativas y comparables que permitan evaluar la alineación
# entre capital operativo (inventario) y generación de ventas.
#
# **Principios**
# - Modelos determinísticos (no ML)
# - Explicables y trazables
# - Enfocados en orientación (OODA), no en recomendación

# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=127.0.0.1,1433;"
    "DATABASE=AdventureWorks2019;"
    "UID=sa;"
    "PWD=S1nt3lo_SQL_2026!;"
    "Encrypt=no;"
    "TrustServerCertificate=yes;"
)

# %%
# Productos
product = pd.read_sql("""
    SELECT
        ProductID,
        Name AS ProductName,
        ProductSubcategoryID,
        StandardCost
    FROM Production.Product
""", conn)

# Inventario (agregado)
inventory = pd.read_sql("""
    SELECT
        ProductID,
        SUM(Quantity) AS QuantityOnHand
    FROM Production.ProductInventory
    GROUP BY ProductID
""", conn)

# Ventas (agregado)
sales = pd.read_sql("""
    SELECT
        ProductID,
        SUM(LineTotal) AS SalesAmount
    FROM Sales.SalesOrderDetail
    GROUP BY ProductID
""", conn)

# Subcategoría
subcategory = pd.read_sql("""
    SELECT
        ProductSubcategoryID,
        ProductCategoryID,
        Name AS ProductSubcategory
    FROM Production.ProductSubcategory
""", conn)

# Categoría
category = pd.read_sql("""
    SELECT
        ProductCategoryID,
        Name AS ProductCategory
    FROM Production.ProductCategory
""", conn)
# Out:
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_56364/1348998874.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product = pd.read_sql("""
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_56364/1348998874.py:12: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   inventory = pd.read_sql("""
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_56364/1348998874.py:21: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales = pd.read_sql("""
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_56364/1348998874.py:30: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   subcategory = pd.read_sql("""
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_56364/1348998874.py:39: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   category = pd.read_sql("""

# %%
df = (
    product
    .merge(inventory, on="ProductID", how="left")
    .merge(sales, on="ProductID", how="left")
    .merge(subcategory, on="ProductSubcategoryID", how="left")
    .merge(category, on="ProductCategoryID", how="left")
)

# %%
df["QuantityOnHand"] = df["QuantityOnHand"].fillna(0)
df["SalesAmount"] = df["SalesAmount"].fillna(0)

df["InventoryValue"] = df["QuantityOnHand"] * df["StandardCost"]

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductID             504 non-null    int64
#  1   ProductName           504 non-null    object
#  2   ProductSubcategoryID  295 non-null    float64
#  3   StandardCost          504 non-null    float64
#  4   QuantityOnHand        504 non-null    float64
#  5   SalesAmount           504 non-null    float64
#  6   ProductCategoryID     295 non-null    float64
#  7   ProductSubcategory    295 non-null    object
#  8   ProductCategory       295 non-null    object
#  9   InventoryValue        504 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 39.5+ KB

# %% [markdown]
# ## Definición del modelo
#
# **Unidades de análisis**
# - Producto (base)
# - Agregación: Categoría
#
# **Proxies**
# - Capital operativo: InventoryValue
# - Retorno observado: SalesAmount
#
# **Supuestos**
# - Inventario es stock observado
# - Ventas son histórico agregado
# - Comparación es relativa (porcentajes), no temporal

# %%
total_inventory = df["InventoryValue"].sum()
total_sales = df["SalesAmount"].sum()

# %%
df["pct_inventory"] = df["InventoryValue"] / total_inventory
df["pct_sales"] = df["SalesAmount"] / total_sales

# %%
model_category = (
    df.groupby("ProductCategory", as_index=False)
      .agg({
          "InventoryValue": "sum",
          "SalesAmount": "sum"
      })
)

model_category["pct_inventory"] = model_category["InventoryValue"] / total_inventory
model_category["pct_sales"] = model_category["SalesAmount"] / total_sales

# %%
model_category
# Out:
#   ProductCategory  InventoryValue   SalesAmount  pct_inventory  pct_sales
# 0     Accessories    8.821176e+04  1.272073e+06       0.004390   0.011580
# 1           Bikes    1.462365e+07  9.465117e+07       0.727810   0.861669
# 2        Clothing    1.381329e+05  2.120543e+06       0.006875   0.019305
# 3      Components    4.375837e+06  1.180259e+07       0.217783   0.107446

# %%
model_category["alignment_gap"] = (
    model_category["pct_sales"] - model_category["pct_inventory"]
)

# %%
model_category[["pct_inventory","pct_sales","alignment_gap"]].sum()
# Out:
# pct_inventory    0.956858
# pct_sales        1.000000
# alignment_gap    0.043142
# dtype: float64

# %%
model_category.columns
# Out:
# Index(['ProductCategory', 'InventoryValue', 'SalesAmount', 'pct_inventory',
#        'pct_sales'],
#       dtype='object')

# %%
model_category["alignment_gap"] = (
    model_category["pct_sales"] - model_category["pct_inventory"]
)

# %%
model_category
# Out:
#   ProductCategory  InventoryValue   SalesAmount  pct_inventory  pct_sales  \
# 0     Accessories    8.821176e+04  1.272073e+06       0.004390   0.011580
# 1           Bikes    1.462365e+07  9.465117e+07       0.727810   0.861669
# 2        Clothing    1.381329e+05  2.120543e+06       0.006875   0.019305
# 3      Components    4.375837e+06  1.180259e+07       0.217783   0.107446
#
#    alignment_gap
# 0       0.007190
# 1       0.133859
# 2       0.012430
# 3      -0.110336

# %%
presentation_table = model_category[[
    "ProductCategory",
    "pct_inventory",
    "pct_sales",
    "alignment_gap"
]].sort_values("alignment_gap", ascending=False)

presentation_table
# Out:
#   ProductCategory  pct_inventory  pct_sales  alignment_gap
# 1           Bikes       0.727810   0.861669       0.133859
# 2        Clothing       0.006875   0.019305       0.012430
# 0     Accessories       0.004390   0.011580       0.007190
# 3      Components       0.217783   0.107446      -0.110336

# %% [markdown]
# ## Cierre — Modeling
#
# Se construyeron métricas relativas y señales de alineación
# entre capital operativo y ventas a nivel categoría.
#
# El siguiente paso (`05_evaluation.ipynb`) evaluará:
# - patrones
# - concentraciones
# - desalineaciones relevantes
# sin emitir recomendaciones.

# %%
df.columns
# Out:
# Index(['ProductID', 'ProductName', 'ProductSubcategoryID', 'StandardCost',
#        'QuantityOnHand', 'SalesAmount', 'ProductCategoryID',
#        'ProductSubcategory', 'ProductCategory', 'InventoryValue',
#        'pct_inventory', 'pct_sales'],
#       dtype='object')

# %%
total_inventory = df["InventoryValue"].sum()
total_sales = df["SalesAmount"].sum()

total_inventory, total_sales
# Out:
# (np.float64(20092679.1712), np.float64(109846381.39988801))

# %%
model_subcategory = (
    df.groupby(
        ["ProductCategory", "ProductSubcategory"],
        as_index=False
    )
    .agg({
        "InventoryValue": "sum",
        "SalesAmount": "sum"
    })
)

# %%
model_subcategory.head()
model_subcategory.columns
# Out:
# Index(['ProductCategory', 'ProductSubcategory', 'InventoryValue',
#        'SalesAmount'],
#       dtype='object')

# %%
model_subcategory["pct_inventory"] = (
    model_subcategory["InventoryValue"] / total_inventory
)

model_subcategory["pct_sales"] = (
    model_subcategory["SalesAmount"] / total_sales
)

# %%
model_subcategory[["pct_inventory", "pct_sales"]].describe()
# Out:
#        pct_inventory  pct_sales
# count      37.000000  37.000000
# mean        0.025861   0.027027
# std         0.071159   0.085510
# min         0.000000   0.000000
# 25%         0.000185   0.000466
# 50%         0.000766   0.001343
# 75%         0.006383   0.003765
# max         0.344771   0.399735

# %%
model_subcategory["alignment_gap"] = (
    model_subcategory["pct_sales"]
    - model_subcategory["pct_inventory"]
)

# %%
model_subcategory.head()
# Out:
#   ProductCategory ProductSubcategory  InventoryValue    SalesAmount  \
# 0     Accessories         Bike Racks          0.0000  237096.156000
# 1     Accessories        Bike Stands       8563.1040   39591.000000
# 2     Accessories  Bottles and Cages       2635.7472   64274.793327
# 3     Accessories           Cleaners        107.0388   18406.972080
# 4     Accessories            Fenders        887.8140   46619.580000
#
#    pct_inventory  pct_sales  alignment_gap
# 0       0.000000   0.002158       0.002158
# 1       0.000426   0.000360      -0.000066
# 2       0.000131   0.000585       0.000454
# 3       0.000005   0.000168       0.000162
# 4       0.000044   0.000424       0.000380

# %%
model_subcategory = model_subcategory.sort_values(
    "alignment_gap", ascending=False
)

# %%
model_subcategory
# Out:
#    ProductCategory ProductSubcategory  InventoryValue   SalesAmount  \
# 12           Bikes     Mountain Bikes    4.771084e+06  3.644544e+07
# 13           Bikes         Road Bikes    6.927376e+06  4.390944e+07
# 33      Components        Road Frames    2.873105e+05  3.851351e+06
# 35      Components     Touring Frames    0.000000e+00  1.642328e+06
# 18        Clothing            Jerseys    4.844514e+04  7.522594e+05
# 5      Accessories            Helmets    1.083546e+04  4.840485e+05
# 0      Accessories         Bike Racks    0.000000e+00  2.370962e+05
# 19        Clothing             Shorts    3.760633e+04  4.136005e+05
# 17        Clothing             Gloves    8.374720e+03  2.435120e+05
# 22        Clothing              Vests    1.538935e+04  2.594884e+05
# 21        Clothing             Tights    1.113602e+04  2.031491e+05
# 15        Clothing         Bib-Shorts    1.202717e+04  1.675586e+05
# 6      Accessories    Hydration Packs    2.221160e+03  1.058264e+05
# 2      Accessories  Bottles and Cages    2.635747e+03  6.427479e+04
# 4      Accessories            Fenders    8.878140e+02  4.661958e+04
# 16        Clothing               Caps    1.993622e+03  5.122945e+04
# 3      Accessories           Cleaners    1.070388e+02  1.840697e+04
# 20        Clothing              Socks    3.160577e+03  2.974513e+04
# 11     Accessories    Tires and Tubes    4.349781e+04  2.464545e+05
# 8      Accessories              Locks    2.598750e+03  1.624022e+04
# 1      Accessories        Bike Stands    8.563104e+03  3.959100e+04
# 10     Accessories              Pumps    5.714741e+03  1.351469e+04
# 25      Components             Chains    5.293107e+03  9.377710e+03
# 9      Accessories           Panniers    3.712500e+03  0.000000e+00
# 7      Accessories             Lights    7.437636e+03  0.000000e+00
# 24      Components             Brakes    7.045614e+04  6.601871e+04
# 27      Components        Derailleurs    8.032741e+04  7.020950e+04
# 30      Components           Headsets    8.992464e+04  6.094220e+04
# 34      Components            Saddles    1.026004e+05  5.582939e+04
# 23      Components    Bottom Brackets    1.085159e+05  5.182637e+04
# 32      Components             Pedals    1.282443e+05  1.474839e+05
# 29      Components         Handlebars    2.161643e+05  1.705913e+05
# 28      Components              Forks    2.173232e+05  7.793169e+04
# 26      Components          Cranksets    3.379897e+05  2.039426e+05
# 14           Bikes      Touring Bikes    2.925193e+06  1.429629e+07
# 31      Components    Mountain Frames    1.671963e+06  4.713930e+06
# 36      Components             Wheels    1.059724e+06  6.808314e+05
#
#     pct_inventory  pct_sales  alignment_gap
# 12       0.237454   0.331786       0.094332
# 13       0.344771   0.399735       0.054964
# 33       0.014299   0.035061       0.020762
# 35       0.000000   0.014951       0.014951
# 18       0.002411   0.006848       0.004437
# 5        0.000539   0.004407       0.003867
# 0        0.000000   0.002158       0.002158
# 19       0.001872   0.003765       0.001894
# 17       0.000417   0.002217       0.001800
# 22       0.000766   0.002362       0.001596
# 21       0.000554   0.001849       0.001295
# 15       0.000599   0.001525       0.000927
# 6        0.000111   0.000963       0.000853
# 2        0.000131   0.000585       0.000454
# 4        0.000044   0.000424       0.000380
# 16       0.000099   0.000466       0.000367
# 3        0.000005   0.000168       0.000162
# 20       0.000157   0.000271       0.000113
# 11       0.002165   0.002244       0.000079
# 8        0.000129   0.000148       0.000019
# 1        0.000426   0.000360      -0.000066
# 10       0.000284   0.000123      -0.000161
# 25       0.000263   0.000085      -0.000178
# 9        0.000185   0.000000      -0.000185
# 7        0.000370   0.000000      -0.000370
# 24       0.003507   0.000601      -0.002906
# 27       0.003998   0.000639      -0.003359
# 30       0.004475   0.000555      -0.003921
# 34       0.005106   0.000508      -0.004598
# 23       0.005401   0.000472      -0.004929
# 32       0.006383   0.001343      -0.005040
# 29       0.010758   0.001553      -0.009205
# 28       0.010816   0.000709      -0.010107
# 26       0.016822   0.001857      -0.014965
# 14       0.145585   0.130148      -0.015437
# 31       0.083213   0.042914      -0.040299
# 36       0.052742   0.006198      -0.046544

# %%
presentation_subcategory = model_subcategory[[
    "ProductCategory",
    "ProductSubcategory",
    "pct_inventory",
    "pct_sales",
    "alignment_gap"
]]

# %%
presentation_subcategory.head()
# Out:
#    ProductCategory ProductSubcategory  pct_inventory  pct_sales  alignment_gap
# 12           Bikes     Mountain Bikes       0.237454   0.331786       0.094332
# 13           Bikes         Road Bikes       0.344771   0.399735       0.054964
# 33      Components        Road Frames       0.014299   0.035061       0.020762
# 35      Components     Touring Frames       0.000000   0.014951       0.014951
# 18        Clothing            Jerseys       0.002411   0.006848       0.004437

# %%
presentation_subcategory = presentation_subcategory.copy()

for col in ["pct_inventory", "pct_sales", "alignment_gap"]:
    presentation_subcategory[col] *= 100

presentation_subcategory
# Out:
#    ProductCategory ProductSubcategory  pct_inventory  pct_sales  alignment_gap
# 12           Bikes     Mountain Bikes      23.745384  33.178557       9.433172
# 13           Bikes         Road Bikes      34.477114  39.973495       5.496380
# 33      Components        Road Frames       1.429926   3.506124       2.076198
# 35      Components     Touring Frames       0.000000   1.495113       1.495113
# 18        Clothing            Jerseys       0.241108   0.684829       0.443720
# 5      Accessories            Helmets       0.053927   0.440660       0.386732
# 0      Accessories         Bike Racks       0.000000   0.215843       0.215843
# 19        Clothing             Shorts       0.187164   0.376526       0.189362
# 17        Clothing             Gloves       0.041680   0.221684       0.180004
# 22        Clothing              Vests       0.076592   0.236228       0.159637
# 21        Clothing             Tights       0.055423   0.184939       0.129516
# 15        Clothing         Bib-Shorts       0.059858   0.152539       0.092681
# 6      Accessories    Hydration Packs       0.011055   0.096340       0.085286
# 2      Accessories  Bottles and Cages       0.013118   0.058513       0.045395
# 4      Accessories            Fenders       0.004419   0.042441       0.038022
# 16        Clothing               Caps       0.009922   0.046637       0.036715
# 3      Accessories           Cleaners       0.000533   0.016757       0.016224
# 20        Clothing              Socks       0.015730   0.027079       0.011349
# 11     Accessories    Tires and Tubes       0.216486   0.224363       0.007877
# 8      Accessories              Locks       0.012934   0.014784       0.001851
# 1      Accessories        Bike Stands       0.042618   0.036042      -0.006576
# 10     Accessories              Pumps       0.028442   0.012303      -0.016139
# 25      Components             Chains       0.026343   0.008537      -0.017806
# 9      Accessories           Panniers       0.018477   0.000000      -0.018477
# 7      Accessories             Lights       0.037017   0.000000      -0.037017
# 24      Components             Brakes       0.350656   0.060101      -0.290555
# 27      Components        Derailleurs       0.399784   0.063916      -0.335868
# 30      Components           Headsets       0.447549   0.055479      -0.392070
# 34      Components            Saddles       0.510636   0.050825      -0.459811
# 23      Components    Bottom Brackets       0.540077   0.047181      -0.492896
# 32      Components             Pedals       0.638264   0.134264      -0.504000
# 29      Components         Handlebars       1.075836   0.155300      -0.920536
# 28      Components              Forks       1.081604   0.070946      -1.010658
# 26      Components          Cranksets       1.682154   0.185662      -1.496492
# 14           Bikes      Touring Bikes      14.558500  13.014804      -1.543696
# 31      Components    Mountain Frames       8.321255   4.291384      -4.029871
# 36      Components             Wheels       5.274180   0.619803      -4.654377
