# %% [markdown]
# # 02 – Data Understanding
# ## AdventureWorks | Capital Operativo
#
# **Propósito**
# Identificar y comprender las fuentes de datos relevantes para analizar
# la alineación entre inventario (uso de capital operativo) y ventas (retorno observable).
#
# Esta etapa se limita a:
# - Inventariar tablas
# - Entender granularidad y claves
# - Identificar campos económicos
#
# No se realizan cálculos ni análisis.

# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=127.0.0.1,1433;"
    "DATABASE=AdventureWorks2019;"
    "UID=sa;"
    "PWD=S1nt3lo_SQL_2026!;"
    "Encrypt=no;"
    "TrustServerCertificate=yes;"
)

# %%
pd.read_sql("SELECT @@VERSION", conn)
# Out:
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_53225/101866107.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("SELECT @@VERSION", conn)
#
# 0  Microsoft SQL Server 2022 (RTM-CU22) (KB506845...

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)
pd.set_option("display.max_rows", 20)

# %%
product = pd.read_sql("SELECT * FROM Production.Product", conn)
product.head(10)
product.info()
product.sample(10, random_state=42)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductID              504 non-null    int64
#  1   Name                   504 non-null    object
#  2   ProductNumber          504 non-null    object
#  3   MakeFlag               504 non-null    bool
#  4   FinishedGoodsFlag      504 non-null    bool
#  5   Color                  256 non-null    object
#  6   SafetyStockLevel       504 non-null    int64
#  7   ReorderPoint           504 non-null    int64
#  8   StandardCost           504 non-null    float64
#  9   ListPrice              504 non-null    float64
#  10  Size                   211 non-null    object
#  11  SizeUnitMeasureCode    176 non-null    object
#  12  WeightUnitMeasureCode  205 non-null    object
#  13  Weight                 205 non-null    float64
# ...

# %% [markdown]
# ### Production.Product — campos potencialmente relevantes (preliminar)
#
# **Identificador**
# - ProductID
#
# **Clasificación / Segmentación**
# - ProductSubcategoryID
# - ProductModelID
# - ProductLine
# - Class
# - Style
#
# **Costos (proxy de capital)**
# - StandardCost
# - ListPrice
#
# **Operación / Estado**
# - MakeFlag
# - FinishedGoodsFlag
# - SafetyStockLevel
# - ReorderPoint
# - DaysToManufacture
#
# **Temporal**
# - SellStartDate
# - SellEndDate

# %%
product_inventory = pd.read_sql("SELECT * FROM Production.ProductInventory", conn)
product_inventory.head(10)
product_inventory.info()
product_inventory.sample(10, random_state=42)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069 entries, 0 to 1068
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     1069 non-null   int64
#  1   LocationID    1069 non-null   int64
#  2   Shelf         1069 non-null   object
#  3   Bin           1069 non-null   int64
#  4   Quantity      1069 non-null   int64
#  5   rowguid       1069 non-null   object
#  6   ModifiedDate  1069 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 58.6+ KB
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_53225/1194855119.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_inventory = pd.read_sql("SELECT * FROM Production.ProductInventory", conn)
# ...

# %% [markdown]
# ### Production.ProductInventory — campos potencialmente relevantes
#
# **Identificador**
# - ProductID
#
# **Ubicación**
# - LocationID
#
# **Inventario (stock)**
# - Quantity
#
# **Temporal**
# - ModifiedDate

# %%
product_subcategory = pd.read_sql("SELECT * FROM Production.ProductSubcategory", conn)
product_subcategory.head(10)
product_subcategory.info()
product_subcategory.sample(10, random_state=42)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductSubcategoryID  37 non-null     int64
#  1   ProductCategoryID     37 non-null     int64
#  2   Name                  37 non-null     object
#  3   rowguid               37 non-null     object
#  4   ModifiedDate          37 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 1.6+ KB
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_53225/1178090182.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_subcategory = pd.read_sql("SELECT * FROM Production.ProductSubcategory", conn)
# ...

# %% [markdown]
# ### Production.ProductSubcategory — campos potencialmente relevantes
#
# - ProductSubcategoryID
# - ProductCategoryID
# - Name

# %%
product_category = pd.read_sql("SELECT * FROM Production.ProductCategory", conn)
product_category.head(10)
product_category.info()
product_category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ProductCategoryID  4 non-null      int64
#  1   Name               4 non-null      object
#  2   rowguid            4 non-null      object
#  3   ModifiedDate       4 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 256.0+ bytes
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_53225/1606074157.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_category = pd.read_sql("SELECT * FROM Production.ProductCategory", conn)
#    ProductCategoryID         Name                               rowguid ModifiedDate
# ...

# %% [markdown]
# ### Production.ProductCategory — campos potencialmente relevantes
#
# - ProductCategoryID
# - Name

# %%
sales_order_detail = pd.read_sql("SELECT * FROM Sales.SalesOrderDetail", conn)
sales_order_detail.head(10)
sales_order_detail.info()
sales_order_detail.sample(10, random_state=42)
# Out:
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_53225/2280692139.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales_order_detail = pd.read_sql("SELECT * FROM Sales.SalesOrderDetail", conn)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121317 entries, 0 to 121316
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   SalesOrderID           121317 non-null  int64
#  1   SalesOrderDetailID     121317 non-null  int64
#  2   CarrierTrackingNumber  60919 non-null   object
#  3   OrderQty               121317 non-null  int64
#  4   ProductID              121317 non-null  int64
#  5   SpecialOfferID         121317 non-null  int64
#  6   UnitPrice              121317 non-null  float64
# ...

# %% [markdown]
# ### Sales.SalesOrderDetail — campos potencialmente relevantes
#
# **Identificadores**
# - SalesOrderID
# - ProductID
#
# **Volumen / Retorno**
# - OrderQty
# - UnitPrice
# - UnitPriceDiscount
# - LineTotal
#
# **Temporal**
# - ModifiedDate

# %%
sales_order_header = pd.read_sql("SELECT * FROM Sales.SalesOrderHeader", conn)
sales_order_header.head(10)
sales_order_header.info()
sales_order_header.sample(10, random_state=42)
# Out:
# /var/folders/ry/4019pgsd4073m3w_k8vm8bqr0000gn/T/ipykernel_53225/206927760.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sales_order_header = pd.read_sql("SELECT * FROM Sales.SalesOrderHeader", conn)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31465 entries, 0 to 31464
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SalesOrderID            31465 non-null  int64
#  1   RevisionNumber          31465 non-null  int64
#  2   OrderDate               31465 non-null  datetime64[ns]
#  3   DueDate                 31465 non-null  datetime64[ns]
#  4   ShipDate                31465 non-null  datetime64[ns]
#  5   Status                  31465 non-null  int64
#  6   OnlineOrderFlag         31465 non-null  bool
# ...

# %% [markdown]
# ### Sales.SalesOrderHeader — campos potencialmente relevantes
#
# **Identificador**
# - SalesOrderID
#
# **Temporal**
# - OrderDate
# - ShipDate
#
# **Geografía / Cliente**
# - CustomerID
# - TerritoryID
#
# **Totales**
# - SubTotal
# - TotalDue

# %% [markdown]
# ## Cierre — Data Understanding
#
# Se identificaron las tablas relevantes, sus granularidades y los campos
# potencialmente útiles para analizar la alineación entre inventario
# (capital operativo) y ventas (retorno observado).
#
# La selección definitiva de campos, definición de claves y construcción
# de la tabla analítica central se realizará en `03_data_preparation.ipynb`.
